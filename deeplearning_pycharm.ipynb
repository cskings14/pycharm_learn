# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-1bf2fed14809> in <module>
# ----> 1 import tensorflow as tf
#       2 print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
#       3
#       4
#
# c:\users\spart\appdata\local\programs\python\python39\lib\site-packages\tensorflow\__init__.py in <module>
#      53 from ._api.v2 import autograph
#      54 from ._api.v2 import bitwise
# ---> 55 from ._api.v2 import compat
#      56 from ._api.v2 import config
#      57 from ._api.v2 import data
#
# c:\users\spart\appdata\local\programs\python\python39\lib\site-packages\tensorflow\_api\v2\compat\__init__.py in <module>
#      37 import sys as _sys
#      38
# ---> 39 from . import v1
#      40 from . import v2
#      41 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# c:\users\spart\appdata\local\programs\python\python39\lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py in <module>
#      32 from . import autograph
#      33 from . import bitwise
# ---> 34 from . import compat
#      35 from . import config
#      36 from . import data
#
# c:\users\spart\appdata\local\programs\python\python39\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py in <module>
#      37 import sys as _sys
#      38
# ---> 39 from . import v1
#      40 from . import v2
#      41 from tensorflow.python.compat.compat import forward_compatibility_horizon
#
# c:\users\spart\appdata\local\programs\python\python39\lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v1\__init__.py in <module>
#      49 from tensorflow._api.v2.compat.v1 import layers
#      50 from tensorflow._api.v2.compat.v1 import linalg
# ---> 51 from tensorflow._api.v2.compat.v1 import lite
#      52 from tensorflow._api.v2.compat.v1 import logging
#      53 from tensorflow._api.v2.compat.v1 import lookup
#
# c:\users\spart\appdata\local\programs\python\python39\lib\site-packages\tensorflow\_api\v2\compat\v1\lite\__init__.py in <module>
#       9
#      10 from . import constants
# ---> 11 from . import experimental
#      12 from tensorflow.lite.python.lite import Interpreter
#      13 from tensorflow.lite.python.lite import OpHint
#
# c:\users\spart\appdata\local\programs\python\python39\lib\site-packages\tensorflow\_api\v2\compat\v1\lite\experimental\__init__.py in <module>
#       8 import sys as _sys
#       9
# ---> 10 from . import nn
#      11 from tensorflow.lite.python.lite import OpResolverType
#      12 from tensorflow.lite.python.lite import convert_op_hints_to_stubs
#
# c:\users\spart\appdata\local\programs\python\python39\lib\site-packages\tensorflow\_api\v2\compat\v1\lite\experimental\nn\__init__.py in <module>
#       8 import sys as _sys
#       9
# ---> 10 from tensorflow.lite.python.lite import TFLiteLSTMCell
#      11 from tensorflow.lite.python.lite import TfLiteRNNCell
#      12 from tensorflow.lite.python.lite import dynamic_rnn
#
# ImportError: cannot import name 'TFLiteLSTMCell' from 'tensorflow.lite.python.lite' (c:\users\spart\appdata\local\programs\python\python39\lib\site-packages\tensorflow\lite\python\lite.py)
